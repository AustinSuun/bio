# %%
import pandas as pd 
import os

# %%
cancer_name = "ACC"  # 癌症名称
indicator = 'DNA_methylation' # 指标

# %%
path = os.path.join("..", "dataset", cancer_name, indicator)
df = pd.read_csv(path, sep="\t", index_col=0).T

# %%
import seaborn as sns
import matplotlib.pyplot as plt

'''sns.heatmap(df.isna(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()'''
# Out:
# 'sns.heatmap(df.isna(), cbar=False, cmap="viridis")\nplt.title("Missing Values Heatmap")\nplt.show()'

# %%
df.shape
# Out:
# (80, 485577)

# %%
import pandas as pd
import os
from sklearn.impute import KNNImputer
import numpy as np

# 设置阈值，比如缺失超过 20% 的列就删掉
threshold = 0.2

# 每列缺失比例
missing_ratio = df.isna().mean()

# 保留缺失比例 <= 20% 的列
df_filtered = df.loc[:, missing_ratio <= threshold]

# %%
df_filtered
# Out:
# sample           cg13332474  cg00651829  cg17027195  cg09868354  cg03050183  \
# TCGA-OR-A5LM-01      0.0218      0.0363      0.0423      0.1117      0.1197
# TCGA-OR-A5K1-01      0.0289      0.0199      0.0352      0.0774      0.0653
# TCGA-OR-A5K2-01      0.5992      0.0270      0.0576      0.0885      0.0862
# TCGA-OR-A5JM-01      0.0307      0.0205      0.0436      0.1201      0.0522
# TCGA-OR-A5LA-01      0.0198      0.0183      0.0338      0.0833      0.0950
# ...                     ...         ...         ...         ...         ...
# TCGA-OR-A5J8-01      0.0548      0.1734      0.0361      0.0710      0.1382
# TCGA-OR-A5JX-01      0.0243      0.0300      0.0357      0.0511      0.0645
# TCGA-OR-A5JC-01      0.0363      0.0598      0.0647      0.0731      0.0398
# TCGA-OR-A5KZ-01      0.0239      0.0274      0.0467      0.0935      0.0634
# TCGA-OR-A5JE-01      0.3721      0.6388      0.0472      0.0902      0.6120
#
# sample           cg06819656  cg04244851  cg19669385  cg04244855  cg17689707  \
# TCGA-OR-A5LM-01      0.6836      0.9366      0.9563      0.9418      0.0167
# TCGA-OR-A5K1-01      0.8838      0.9256      0.9174      0.8689      0.0155
# TCGA-OR-A5K2-01      0.8545      0.9420      0.9556      0.9426      0.7997
# TCGA-OR-A5JM-01      0.8409      0.9279      0.9622      0.8687      0.6530
# TCGA-OR-A5LA-01      0.8719      0.9508      0.7901      0.9590      0.0177
# ...                     ...         ...         ...         ...         ...
# TCGA-OR-A5J8-01      0.9020      0.9369      0.9646      0.7835      0.0625
# TCGA-OR-A5JX-01      0.7732      0.9440      0.9651      0.9366      0.0168
# TCGA-OR-A5JC-01      0.7866      0.9255      0.8971      0.9273      0.0175
# TCGA-OR-A5KZ-01      0.8512      0.8630      0.9591      0.7456      0.0152
# TCGA-OR-A5JE-01      0.8634      0.9233      0.9531      0.9413      0.7762
#
# sample           ...  cg19358568  cg27295654  cg03116837  cg15678817  \
# TCGA-OR-A5LM-01  ...      0.9525      0.8739      0.1272      0.7750
# TCGA-OR-A5K1-01  ...      0.9352      0.4584      0.1796      0.7605
# TCGA-OR-A5K2-01  ...      0.6015      0.8837      0.6795      0.8585
# TCGA-OR-A5JM-01  ...      0.9383      0.8768      0.8205      0.8147
# TCGA-OR-A5LA-01  ...      0.9467      0.8811      0.8474      0.6315
# ...              ...         ...         ...         ...         ...
# TCGA-OR-A5J8-
GA-OR-A5J5-01, TCGA-PA-A5YG-01, TCGA-OR-A5JY-01, TCGA-OR-A5LE-01, TCGA-OR-A5L3-01, TCGA-OR-A5LN-01, TCGA-OR-A5JW-01, TCGA-PK-A5HA-01, TCGA-OR-A5J7-01, TCGA-OR-A5JR-01, TCGA-OR-A5JD-01, TCGA-OR-A5LR-01, TCGA-PK-A5H8-01, TCGA-OR-A5JQ-01, TCGA-OR-A5JL-01, TCGA-OR-A5JK-01, TCGA-OR-A5LB-01, TCGA-OR-A5LH-01, TCGA-OR-A5JV-01, TCGA-OR-A5JS-01, TCGA-OR-A5LD-01, TCGA-OR-A5LG-01, TCGA-OR-A5JF-01, TCGA-OR-A5JB-01, TCGA-OR-A5LS-01, TCGA-OR-A5K8-01, TCGA-PK-A5H9-01, TCGA-OR-A5LO-01, TCGA-OR-A5J8-01, TCGA-OR-A5JX-01, TCGA-OR-A5JC-01, TCGA-OR-A5KZ-01, TCGA-OR-A5JE-01]
#
# [81 rows x 0 columns]

# %%
df_numeric = df_filtered.select_dtypes(include=[np.number])

# 创建插补器对象
imputer = KNNImputer(n_neighbors=5)  # 5个最近邻

# 拟合并转换
arr_filled = imputer.fit_transform(df_numeric)

df_filled = pd.DataFrame(arr_filled, index=df_numeric.index, columns=df_numeric.columns)

import os

path = os.path.join("..", "dataset", "ACC", "DNA_methylation_filled")
df_filled.to_csv(path)

# %%
df_filled
# Out:
# sample           cg13332474  cg00651829  cg17027195  cg09868354  cg03050183  \
# TCGA-OR-A5LM-01      0.0218      0.0363      0.0423      0.1117      0.1197
# TCGA-OR-A5K1-01      0.0289      0.0199      0.0352      0.0774      0.0653
# TCGA-OR-A5K2-01      0.5992      0.0270      0.0576      0.0885      0.0862
# TCGA-OR-A5JM-01      0.0307      0.0205      0.0436      0.1201      0.0522
# TCGA-OR-A5LA-01      0.0198      0.0183      0.0338      0.0833      0.0950
# ...                     ...         ...         ...         ...         ...
# TCGA-OR-A5J8-01      0.0548      0.1734      0.0361      0.0710      0.1382
# TCGA-OR-A5JX-01      0.0243      0.0300      0.0357      0.0511      0.0645
# TCGA-OR-A5JC-01      0.0363      0.0598      0.0647      0.0731      0.0398
# TCGA-OR-A5KZ-01      0.0239      0.0274      0.0467      0.0935      0.0634
# TCGA-OR-A5JE-01      0.3721      0.6388      0.0472      0.0902      0.6120
#
# sample           cg06819656  cg04244851  cg19669385  cg04244855  cg17689707  \
# TCGA-OR-A5LM-01      0.6836      0.9366      0.9563      0.9418      0.0167
# TCGA-OR-A5K1-01      0.8838      0.9256      0.9174      0.8689      0.0155
# TCGA-OR-A5K2-01      0.8545      0.9420      0.9556      0.9426      0.7997
# TCGA-OR-A5JM-01      0.8409      0.9279      0.9622      0.8687      0.6530
# TCGA-OR-A5LA-01      0.8719      0.9508      0.7901      0.9590      0.0177
# ...                     ...         ...         ...         ...         ...
# TCGA-OR-A5J8-
#
# sample           cg07883722
# TCGA-OR-A5J8-01      0.9458
# TCGA-OR-A5JX-01      0.9180
# TCGA-OR-A5JC-01      0.9449
# TCGA-OR-A5KZ-01      0.5350
# TCGA-OR-A5JE-01      0.9565
#
# [5 rows x 485577 columns]

# %%
df.sample(5) # 随机查看5行
# Out:
# sample           cg13332474  cg00651829  cg17027195  cg09868354  cg03050183  \
# TCGA-OR-A5J7-01      0.0269      0.4307      0.0347      0.1066      0.0637
# TCGA-OR-A5KV-01      0.0305      0.0188      0.0398      0.0978      0.0503
# TCGA-OR-A5LO-01      0.0207      0.0219      0.0284      0.0393      0.0752
# TCGA-OR-A5JV-01      0.0230      0.0222      0.0389      0.0908      0.0547
# TCGA-OR-A5J4-01      0.0268      0.0220      0.0532      0.0780      0.6248
#
# sample           cg01989731  cg06819656  cg04244851  cg19669385  cg04244855  \
# TCGA-OR-A5J7-01         NaN      0.8859      0.9376      0.9579      0.9404
# TCGA-OR-A5KV-01         NaN      0.8518      0.9449      0.9592      0.9428
# TCGA-OR-A5LO-01         NaN      0.8492      0.9310      0.9524      0.9422
# TCGA-OR-A5JV-01         NaN      0.7669      0.9432      0.7323      0.9407
# TCGA-OR-A5J4-01         NaN      0.9314      0.9141      0.9124      0.9182
#
# sample           ...  cg14483317  cg05534403  cg04487158  cg00810133  \
# TCGA-OR-A5J7-01  ...      0.0466         NaN         NaN         NaN
# TCGA-OR-A5KV-01  ...      0.0293         NaN         NaN         NaN
# TCGA-OR-A5LO-01  ...      0.1678         NaN         NaN         NaN
# TCGA-OR-A5JV-01  ...      0.0332         NaN         NaN         NaN
# TCGA-OR-A5J4-01  ...      0.0476         NaN         NaN         NaN
#
# sample           cg11692435  cg16018548  cg10230711  cg16651827  cg18138552  \
# TCGA-OR-A5J7-01      0.9845         NaN      0.0832      0.7618      0.0360
# TCGA-OR-A5KV-01      0.9905         NaN      0.0532      0.7599      0.0290
# TCGA-OR-A5LO-01      0.9848         NaN      0.0588      0.7694      0.0339
# TCGA-OR-A5JV-01      0.9283         NaN      0.0612      0.7832      0.0448
# TCGA-OR-A5J4-01      0.9809         NaN      0.0541      0.5828      0.0357
#
# sample           cg07883722
# TCGA-OR-A5J7-01      0.9487
# TCGA-OR-A5KV-01      0.9389
# TCGA-OR-A5LO-01      0.9427
# TCGA-OR-A5JV-01      0.6693
# TCGA-OR-A5J4-01      0.9502
#
# [5 rows x 485577 columns]

# %%
df.shape # 查看表格行列数
# Out:
# (80, 485577)

# %%
df.columns # 查看列名
# Out:
# Index(['cg13332474', 'cg00651829', 'cg17027195', 'cg09868354', 'cg03050183',
#        'cg01989731', 'cg06819656', 'cg04244851', 'cg19669385', 'cg04244855',
#        ...
#        'cg14483317', 'cg05534403', 'cg04487158', 'cg00810133', 'cg11692435',
#        'cg16018548', 'cg10230711', 'cg16651827', 'cg18138552', 'cg07883722'],
#       dtype='object', name='sample', length=485577)

# %%
df.info() # 查看信息 缺失等
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, TCGA-OR-A5LM-01 to TCGA-OR-A5JE-01
# Columns: 485577 entries, cg13332474 to cg07883722
# dtypes: float64(485577)
# memory usage: 296.4+ MB

# %%
df.describe() # 列出列的统计信息
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.describe() # 列出列的统计信息
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)  11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)  11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/methods/describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/methods/describe.py:172, in DataFrameDescriber.describe(self, percentiles)
#     170 for _, series in data.items():
#     171     describe_func = select_describe_func(series)
# --> 172     ldesc.append(describe_func(series, percentiles))
#     174 col_names = reorder_columns(ldesc)
#     175 d = concat(
#     176     [x.reindex(col_names, copy=False) for x in ldesc],
#     177     axis=1,
#     178     sort=False,
#     179 )
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/methods/describe.py:233, in describe_numeric_1d(series, percentiles)
#     229 formatted_percentiles = format_percentiles(percentiles)
#     231 stat_index = ["count", "mean", "std", "min"] + formatted_percentiles + ["max"]
#     232 d = (
# --> 233     [series.count(), series.mean(), series.std(), series.min()]
#     234     + series.quantile(percentiles).tolist()
#     235     + [series.max()]
#     236 )
#     237 # GH#48340 - always return float on non-complex numeric data
#     238 dtype: DtypeObj | None
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/series.py:6592, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6583 @doc(make_doc("std", ndim=1))
#    6584 def std(
#    6585     self,
#    (...)   6590     **kwargs,
#    6591 ):
# -> 6592     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/generic.py:12358, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12350 def std(
#   12351     self,
#   12352     axis: Axis | None = 0,
#    (...)  12356     **kwargs,
#   12357 ) -> Series | float:
# > 12358     return self._stat_function_ddof(
#   12359         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12360     )
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/generic.py:12322, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12319 elif axis is lib.no_default:
#   12320     axis = 0
# > 12322 return self._reduce(
#   12323     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324 )
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/nanops.py:79, in disallow.__call__.<locals>._f(*args, **kwargs)
#      76 @functools.wraps(f)
#      77 def _f(*args, **kwargs):
#      78     obj_iter = itertools.chain(args, kwargs.values())
# ---> 79     if any(self.check(obj) for obj in obj_iter):
#      80         f_name = f.__name__.replace("nan", "")
#      81         raise TypeError(
#      82             f"reduction operation '{f_name}' not allowed for this dtype"
#      83         )
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/nanops.py:79, in <genexpr>(.0)
#      76 @functools.wraps(f)
#      77 def _f(*args, **kwargs):
#      78     obj_iter = itertools.chain(args, kwargs.values())
# ---> 79     if any(self.check(obj) for obj in obj_iter):
#      80         f_name = f.__name__.replace("nan", "")
#      81         raise TypeError(
#      82             f"reduction operation '{f_name}' not allowed for this dtype"
#      83         )
#
# File ~/.conda/envs/d2l/lib/python3.12/site-packages/pandas/core/nanops.py:72, in disallow.check(self, obj)
#      69     super().__init__()
#      70     self.dtypes = tuple(pandas_dtype(dtype).type for dtype in dtypes)
# ---> 72 def check(self, obj) -> bool:
#      73     return hasattr(obj, "dtype") and issubclass(obj.dtype.type, self.dtypes)
#      75 def __call__(self, f: F) -> F:
#
# KeyboardInterrupt:

# %%
# progCAE的样例数据
cancer_name = "data"  # 癌症名称
indicator = "example_Meth.csv"  # 指标
path = os.path.join("..", "dataset", cancer_name, indicator)
df2 = pd.read_csv(path).T

# %%
df2.head()
# Out:
#                         0                1                2    \
# Unnamed: 0  TCGA-E9-A228-01  TCGA-D8-A1J8-01  TCGA-AC-A3YI-01
# cg14577840           0.9047           0.9151           0.8807
# cg14196011           0.9618           0.9211           0.8791
# cg09238520           0.9399           0.9359           0.8901
# cg27345735           0.2812           0.2311           0.1892
#
#                         3                4                5    \
# Unnamed: 0  TCGA-OL-A66J-01  TCGA-EW-A1IX-01  TCGA-B6-A1KF-01
# cg14577840           0.9253           0.8981           0.9194
# cg14196011           0.9248           0.9219           0.9209
# cg09238520           0.9259           0.9351           0.9378
# cg27345735           0.2174           0.2073            0.242
#
#                         6                7                8    \
# Unnamed: 0  TCGA-C8-A1HO-01  TCGA-BH-A1F5-01  TCGA-XX-A89A-01
# cg14577840           0.9114            0.902           0.8699
# cg14196011            0.937           0.9285           0.8473
# cg09238520           0.9393            0.921           0.8744
# cg27345735           0.1949           0.3482            0.207
#
#                         9    ...              601              602  \
# Unnamed: 0  TCGA-D8-A27K-01  ...  TCGA-BH-A0BT-01  TCGA-EW-A1PE-01
# cg14577840           0.8987  ...            0.833           0.9294
# cg14196011           0.9074  ...           0.8814           0.9286
# cg09238520           0.9264  ...           0.8825           0.9458
# cg27345735           0.2411  ...           0.2492           0.2223
#
#                         603              604              605  \
# Unnamed: 0  TCGA-OL-A5RX-01  TCGA-E2-A1AZ-01  TCGA-AC-A8OR-01
# cg14577840           0.9111           0.9124            0.802
# cg14196011           0.8979           0.9231           0.8292
# cg09238520           0.8921           0.9312           0.8376
# cg27345735           0.1642           0.3479           0.1807
#
#                         606              607              608  \
# Unnamed: 0  TCGA-MS-A51U-01  TCGA-EW-A1IY-01  TCGA-BH-A1FN-01
# cg14577840           0.8691           0.8803           0.8872
# cg14196011           0.8439           0.9315           0.9215
# cg09238520           0.8581           0.9248           0.9312
# cg27345735           0.1532           0.2185           0.3334
#
#                         609              610
# Unnamed: 0  TCGA-E2-A3DX-01  TCGA-E9-A1RF-01
# cg14577840           0.8807           0.9234
# cg14196011           0.9195           0.9261
# cg09238520           0.9087           0.9291
# cg27345735           0.1994           0.3463
#
# [5 rows x 611 columns]

# %%
df2.shape
# Out:
# (3001, 611)
